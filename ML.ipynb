# %% [markdown]
# <a href="https://colab.research.google.com/github/rathoretanya76-art/Tan/blob/main/ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Load dataset
df = pd.read_csv("Resume.csv")

# Assume columns: 'Resume' and 'Category'
X = df['Resume_str'] # Changed 'Resume' to 'Resume_str'
y = df['Category']

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# TF-IDF
tfidf = TfidfVectorizer(stop_words='english')
X_train_vec = tfidf.fit_transform(X_train)
X_test_vec = tfidf.transform(X_test)

# Model
model = LogisticRegression(max_iter=1000)
model.fit(X_train_vec, y_train)

# Prediction
y_pred = model.predict(X_test_vec)

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6277665995975855

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train_vec, y_train)

print(knn.predict(X_test_vec[:5]))
# Out:
# ['BANKING' 'CONSTRUCTION' 'BUSINESS-DEVELOPMENT' 'ADVOCATE' 'ACCOUNTANT']

# %%
from sklearn.naive_bayes import MultinomialNB

nb = MultinomialNB()
nb.fit(X_train_vec, y_train)

print("NB Accuracy:", nb.score(X_test_vec, y_test))
# Out:
# NB Accuracy: 0.48490945674044267
